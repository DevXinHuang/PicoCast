# %% [markdown]
# # Candidate Replay
#
# Load generated candidates and inspect their scores and locations.

# %%
from pathlib import Path

import pandas as pd

candidate_path = Path('../data/candidates/candidate_detections.parquet')
if candidate_path.exists():
    candidates = pd.read_parquet(candidate_path)
    display(candidates)
else:
    print('Run nexrad-pico detect first.')
