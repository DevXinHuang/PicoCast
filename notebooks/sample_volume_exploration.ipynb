# %% [markdown]
# # Sample Volume Exploration
#
# Use this notebook to inspect a synthetic or decoded Level II volume.

# %%
from nexrad_picoballoon.features import extract_gate_features
from nexrad_picoballoon.synthetic import make_synthetic_volume

ds = make_synthetic_volume()
features = extract_gate_features(ds)
features.head()
# Out:
#     site                  scan_time source_path  azimuth_deg  range_m  \
# 0  KTEST  2026-01-01T00:00:00+00:00                      0.0   1000.0
# 1  KTEST  2026-01-01T00:00:00+00:00                      0.0   2000.0
# 2  KTEST  2026-01-01T00:00:00+00:00                      0.0   3000.0
# 3  KTEST  2026-01-01T00:00:00+00:00                      0.0   4000.0
# 4  KTEST  2026-01-01T00:00:00+00:00                      0.0   5000.0
#
#     latitude  longitude  altitude_m  reflectivity_dbz  velocity_ms  \
# 0  35.008993      -97.0  378.726535             -12.0          0.0
# 1  35.017986      -97.0  387.453071             -12.0          0.0
# 2  35.026979      -97.0  396.179606             -12.0          0.0
# 3  35.035971      -97.0  404.906142             -12.0          0.0
# 4  35.044964      -97.0  413.632677             -12.0          0.0
#
#    spectrum_width_ms  rhohv  zdr_db  phidp_deg  rhohv_texture  zdr_texture  \
# ...
